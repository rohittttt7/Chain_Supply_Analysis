# %%
import pandas as pd

main = pd.read_excel("Retail-Supply-Chain-Sales-Dataset.xlsx", sheet_name="Retails Order Full Dataset")
cal = pd.read_excel("Retail-Supply-Chain-Sales-Dataset.xlsx", sheet_name="Calendar Table")

# %%
main.head(15)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 1        2  CA-2016-152156 2016-08-11 2016-11-11    Second Class    CG-12520
# 2        3  CA-2016-138688 2016-12-06 2016-12-06    Second Class    DV-13045
# 3        4  US-2015-108966 2015-11-10 2015-11-10  Standard Class    SO-20335
# 4        5  US-2015-108966 2015-11-10 2015-11-10  Standard Class    SO-20335
# 5        6  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# 6        7  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# 7        8  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# 8        9  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# 9       10  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# 10      11  CA-2014-115812 2014-09-06 2014-09-06  Standard Class    BH-11710
# ...

# %%
cal.head(10)
# Out:
#         Date  Year  Quarter Quarter (Q) Quarter & Year  Month Month Name  \
# 0 2016-07-01  2016        3          Q3      2016 - Q3      7        Jul
# 1 2016-07-02  2016        3          Q3      2016 - Q3      7        Jul
# 2 2016-07-03  2016        3          Q3      2016 - Q3      7        Jul
# 3 2016-07-04  2016        3          Q3      2016 - Q3      7        Jul
# 4 2016-07-05  2016        3          Q3      2016 - Q3      7        Jul
# 5 2016-07-06  2016        3          Q3      2016 - Q3      7        Jul
# 6 2016-07-07  2016        3          Q3      2016 - Q3      7        Jul
# 7 2016-07-08  2016        3          Q3      2016 - Q3      7        Jul
# 8 2016-07-09  2016        3          Q3      2016 - Q3      7        Jul
# 9 2016-07-10  2016        3          Q3      2016 - Q3      7        Jul
#
#   Month & Year  Week of Year Week of Year (W)  Day of Week   Day Name
# 0     Jul 2016            27          Week 27            5     Friday
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Row ID               9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   datetime64[ns]
#  3   Ship Date            9994 non-null   datetime64[ns]
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Country              9994 non-null   object
#  9   City                 9994 non-null   object
#  10  State                9994 non-null   object
#  11  Postal Code          9994 non-null   int64
#  12  Region               9994 non-null   object
#  13  Retail Sales People  9994 non-null   object
#  14  Product ID           9994 non-null   object
# ...

# %%
cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1826 non-null   datetime64[ns]
#  1   Year              1826 non-null   int64
#  2   Quarter           1826 non-null   int64
#  3   Quarter (Q)       1826 non-null   object
#  4   Quarter & Year    1826 non-null   object
#  5   Month             1826 non-null   int64
#  6   Month Name        1826 non-null   object
#  7   Month & Year      1826 non-null   object
#  8   Week of Year      1826 non-null   int64
#  9   Week of Year (W)  1826 non-null   object
#  10  Day of Week       1826 non-null   int64
#  11  Day Name          1826 non-null   object
# dtypes: datetime64[ns](1), int64(5), object(6)
# memory usage: 171.3+ KB

# %%
main.isnull().sum()
# Out:
# Row ID                 0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Postal Code            0
# Region                 0
# Retail Sales People    0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Returned               0
# Sales                  0
# Quantity               0
# Discount               0
# Profit                 0
# dtype: int64

# %%
cal.isnull().sum()
# Out:
# Date                0
# Year                0
# Quarter             0
# Quarter (Q)         0
# Quarter & Year      0
# Month               0
# Month Name          0
# Month & Year        0
# Week of Year        0
# Week of Year (W)    0
# Day of Week         0
# Day Name            0
# dtype: int64

# %%
main.shape
# Out:
# (9994, 23)

# %%
cal.shape
# Out:
# (1826, 12)

# %%
main.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-11 07:17:44.078447104
# min       1.000000            2014-01-02 00:00:00
# 25%    2499.250000            2015-05-01 00:00:00
# 50%    4997.500000            2016-05-30 00:00:00
# 75%    7495.750000            2017-04-09 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-15 21:54:47.332399360  55190.379428    229.858001     3.789574
# min              2014-01-15 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-06-20 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-07-21 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
cal.describe()
# Out:
#                       Date         Year      Quarter        Month  \
# count                 1826  1826.000000  1826.000000  1826.000000
# mean   2016-07-01 12:00:00  2016.000000     2.508762     6.523549
# min    2014-01-01 00:00:00  2014.000000     1.000000     1.000000
# 25%    2015-04-02 06:00:00  2015.000000     2.000000     4.000000
# 50%    2016-07-01 12:00:00  2016.000000     3.000000     7.000000
# 75%    2017-09-30 18:00:00  2017.000000     4.000000    10.000000
# max    2018-12-31 00:00:00  2018.000000     4.000000    12.000000
# std                    NaN     1.414214     1.117326     3.449478
#
#        Week of Year  Day of Week
# count   1826.000000  1826.000000
# mean      27.014239     4.001095
# min        1.000000     1.000000
# 25%       14.000000     2.000000
# 50%       27.000000     4.000000
# 75%       40.000000     6.000000
# max       53.000000     7.000000
# std       15.069985     2.000548

# %%
main.columns=main.columns.str.lower()

# %%
main.columns=main.columns.str.replace(" ","_")

# %%
main.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'retail_sales_people', 'product_id',
#        'category', 'sub-category', 'product_name', 'returned', 'sales',
#        'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
main.columns=main.columns.str.replace("-","_")

# %%
main.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'retail_sales_people', 'product_id',
#        'category', 'sub_category', 'product_name', 'returned', 'sales',
#        'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
cal.columns=cal.columns.str.lower()

# %%
cal.columns=cal.columns.str.replace(" ","_")

# %%
cal.columns
# Out:
# Index(['date', 'year', 'quarter', 'quarter_(q)', 'quarter_&_year', 'month',
#        'month_name', 'month_&_year', 'week_of_year', 'week_of_year_(w)',
#        'day_of_week', 'day_name'],
#       dtype='object')

# %%
main['order_date']=pd.to_datetime(main['order_date'])
main['ship_date']=pd.to_datetime(main['ship_date'])

cal['date']=pd.to_datetime(cal['date'])

# %%
main['delivery_date']=(main['ship_date']-main['order_date']).dt.days

# %%
main.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'retail_sales_people', 'product_id',
#        'category', 'sub_category', 'product_name', 'returned', 'sales',
#        'quantity', 'discount', 'profit', 'delivery_date'],
#       dtype='object')

# %%
main['profit_margin']=(main['profit']/main['sales']*100)

# %%
main=main.merge(cal,left_on='order_date',right_on='date',how='left')

# %%
main.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'retail_sales_people', 'product_id',
#        'category', 'sub_category', 'product_name', 'returned', 'sales',
#        'quantity', 'discount', 'profit', 'delivery_date', 'profit_margin',
#        'date', 'year', 'quarter', 'quarter_(q)', 'quarter_&_year', 'month',
#        'month_name', 'month_&_year', 'week_of_year', 'week_of_year_(w)',
#        'day_of_week', 'day_name'],
#       dtype='object')

# %%
total_sales=main['sales'].sum()
print(total_sales)
# Out:
# 2297200.8603000003

# %%
total_profit=main['profit'].sum()
print(total_profit)
# Out:
# 286397.0217

# %%
total_order=main['order_id'].nunique()
print(total_order)
# Out:
# 5009

# %%
total_customer=main['customer_id'].nunique()
print(total_customer)
# Out:
# 793

# %%
main.duplicated('customer_id').sum()
# Out:
# np.int64(9201)

# %%
main['order_id'].value_counts().head()
# Out:
# order_id
# CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# US-2015-126977    10
# Name: count, dtype: int64

# %%
main[main['order_id'] == 'CA-2016-152156']
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 6090    6091  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6091    6092  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6092    6093  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6093    6094  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6094    6095  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6095    6096  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6096    6097  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6097    6098  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6098    6099  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6099    6100  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6100    6101  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6101    6102  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6102    6103  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# ...

# %%
return_rate=main['returned'].value_counts(normalize='True')*100
return_rate
# Out:
# returned
# Not    91.995197
# Yes     8.004803
# Name: proportion, dtype: float64

# %%
main.groupby('customer_name')['sales'].sum().sort_values(ascending=False).head(10)
# Out:
# customer_name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: sales, dtype: float64

# %%
main.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'retail_sales_people', 'product_id',
#        'category', 'sub_category', 'product_name', 'returned', 'sales',
#        'quantity', 'discount', 'profit', 'delivery_date', 'profit_margin',
#        'date', 'year', 'quarter', 'quarter_(q)', 'quarter_&_year', 'month',
#        'month_name', 'month_&_year', 'week_of_year', 'week_of_year_(w)',
#        'day_of_week', 'day_name'],
#       dtype='object')

# %%
main.groupby('retail_sales_people')['profit'].sum().sort_values(ascending=False)
# Out:
# retail_sales_people
# Anna Andreadi        108418.4489
# Chuck Magee           91522.7800
# Cassandra Brandow     46749.4303
# Kelly Williams        39706.3625
# Name: profit, dtype: float64

# %%
main[main['profit']<0]
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 3          4  US-2015-108966 2015-11-10 2015-11-10  Standard Class
# 14        15  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 15        16  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 23        24  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 27        28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 9920    9921  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 9921    9922  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
# 9931    9932  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# 9937    9938  CA-2016-164889 2016-03-06 2016-06-06    Second Class
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#      customer_id     customer_name      segment        country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %%
from sqlalchemy import create_engine

# step 1: conncet to postgresql
# replace placholder with your actual details
username="root"
password="rohit"
host="localhost"
port="3306"
database="retail_supply_chain"

engine=create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
# step 2 : load dataframe into postgreaql
table_name= "customer"  #choose any table name
main.to_sql(table_name,engine,if_exists="replace",index=False)
print(f"data successfull load into table'{table_name}' in database '{database} ',")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:143, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     142 try:
# --> 143     self._dbapi_connection = engine.raw_connection()
#     144 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3301, in Engine.raw_connection(self)
#    3280 """Return a "raw" DBAPI connection from the connection pool.
#    3281
#    3282 The returned object is a proxied version of the DBAPI
#    (...)   3299
#    3300 """
# -> 3301 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:447, in Pool.connect(self)
#     440 """Return a DBAPI connection from the pool.
#     441
#     442 The connection is instrumented such that when its
# ...
